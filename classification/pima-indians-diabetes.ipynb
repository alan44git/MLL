# %%
import kagglehub
path = kagglehub.dataset_download("kumargh/pimaindiansdiabetescsv")
# !mv $path "./" && mv "./1/pima-indians-diabetes.csv" "./" && rm -rf 1
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/kumargh/pimaindiansdiabetescsv?dataset_version_number=1...
# 100%|██████████| 8.89k/8.89k [00:00<00:00, 373kB/s]
# Extracting files...

# %%
import pandas as pd
df = pd.read_csv("pima-indians-diabetes.csv")
df.shape
# Out:
# (767, 9)

# %%
df.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
df.isna().any()
# Out:
# 6        False
# 148      False
# 72       False
# 35       False
# 0        False
# 33.6     False
# 0.627    False
# 50       False
# 1        False
# dtype: bool

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data = df, x="1")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
X = df[["50"]]
y = df["1"]
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3,random_state = 62)
nb = MultinomialNB(alpha = 1.0)
nb.fit(X_train, y_train)
y_pred = nb.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82       162
#            1       0.00      0.00      0.00        69
#
#     accuracy                           0.70       231
#    macro avg       0.35      0.50      0.41       231
# weighted avg       0.49      0.70      0.58       231
# D:\PICT\TE\SEM 5\ML\venv\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\PICT\TE\SEM 5\ML\venv\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\PICT\TE\SEM 5\ML\venv\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
